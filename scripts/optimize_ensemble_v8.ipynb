# %% [markdown]
# # ensemble

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize, StandardScaler
import glob
import tqdm
import torch

# %%
df = pd.read_csv("../input/shopee-product-matching/train_fold.csv")
df = df[df["fold"] == 0]
tmp = df.groupby('label_group').posting_id.agg('unique').to_dict()
df['target'] = df.label_group.map(tmp)

# %%
posting_id = df["posting_id"].values

# %%
def get_cosine_similarity(embeddings):

    CHUNK = 1024 * 2
    CTS = len(embeddings) // CHUNK
    if (len(embeddings)%CHUNK) != 0:
        CTS += 1
    distances = []
    
    with torch.no_grad():
        embeddings = normalize(embeddings)
        embeddings = torch.tensor(embeddings).cuda()

        for j in range( CTS ):
            a = j * CHUNK
            b = (j+1) * CHUNK
            b = min(b, len(embeddings))
            # print('chunk', a, 'to', b)

            # COSINE SIMILARITY DISTANCE
            cts = torch.matmul(embeddings, embeddings[a:b].T).T
            distances.append(cts.detach().cpu().numpy())
    
    return np.concatenate(distances)

# %%
def get_cv(df, similarity_matrix, threshold, posting_id, indices=None, pred_name="pred", min_n=2, mode="min"):
    preds = []
    for k in range(len(df)):
        if mode == "min": # euclid distance etc
            IDX = np.where(similarity_matrix[k, ] < threshold)[0]
            if len(IDX) < min_n:                
                IDX = np.argsort(similarity_matrix[k, ])[:min_n]
        if mode == "max": # cosine similarlity
            IDX = np.where(similarity_matrix[k, ] > threshold)[0]
            if len(IDX) < min_n:                
                IDX = np.argsort(similarity_matrix[k, ])[-min_n:]
            
        pred = posting_id[IDX]
        preds.append(pred)
    
    df[pred_name] = preds
    f1score, precision, recall = calc_cv(df, col_name=pred_name)
    return f1score, precision, recall

# %%
def calc_cv(df, col_name):
    tmp = df.groupby('label_group').posting_id.agg('unique').to_dict()
    df['target'] = df.label_group.map(tmp)
    df['f1'] = df.apply(get_f1(col_name),axis=1)
    df["precision"] = df.apply(get_precision(col_name), axis=1)
    df["recall"] = df.apply(get_recall(col_name), axis=1)
    return df["f1"].mean(), df["precision"].mean(), df["recall"].mean()

def get_f1(col):
    def f1score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        return 2*n / (len(row.target)+len(row[col]))
    return f1score

def get_precision(col):
    def precision_score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        if len(row[col]) == 0:
            return 0
        else:
            return n / len(row[col])
    return precision_score

def get_recall(col):
    def recall_score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        return n / len(row.target)
    return recall_score

# %%
df_kiccho = pd.read_csv("kiccho-san/valid_df_0.csv")
df_kiccho = pd.merge(df, df_kiccho.reset_index()[["posting_id", "index"]])
kiccho_index = df_kiccho["index"].values

# %%
def get_best_epochs(model_path, early_stopping_round=3):
    file_len = len(glob.glob(f"{model_path}/indices_epoch*.npy"))
    return file_len - early_stopping_round - 1 # epoch は0はじまりなのでさらに1ひく


model_dict = {
    # "bert": "../output/exp044/20210420161425", # CV: 0.862
    # "xlm_roberta": "../output/exp057/20210422123000", # CV: 0.855
    "distilbert": "../output/exp057_3/20210423001437", # CV: 0.857
    # "bert_transformer": "../output/exp058_2/20210423035344" # CV: 0.854,    
    "bert_seresnet": "../output/exp019/20210415123913"
}

model_dist_dict = {}
    
for k, path in model_dict.items():
    best_epochs = get_best_epochs(path)
    
    model_dist_dict[k] = {
        "embeddings":  np.load(f"{path}/embeddings_epoch{best_epochs}.npy")
    }
    
    model_dist_dict[k]["cosine_similarity"] = get_cosine_similarity(model_dist_dict[k]["embeddings"])

model_dist_dict["bert2"] = {
    "embeddings": np.load("../output/exp061/20210424002201/embeddings_epoch8.npy"),
    "cosine_similarity": get_cosine_similarity(np.load("../output/exp061/20210424002201/embeddings_epoch8.npy"))
}
model_dist_dict["exp303"] = {
    "embeddings": np.load("kiccho-san/exp303/features_0_08.npy")[kiccho_index],
    "cosine_similarity": get_cosine_similarity(np.load("kiccho-san/exp303/features_0_08.npy")[kiccho_index])
}

# %%
embeddings = np.array([normalize(model_dist_dict[k]["embeddings"]) for k in model_dict.keys()])

# %%
np.concatenate(embeddings, axis=1).shape
# Out:
# (6839, 1024)

# %%
similarity_concat = get_cosine_similarity(np.concatenate(embeddings, axis=1))
similarity_mean = get_cosine_similarity(embeddings.mean(axis=0))

# %%
def combine_predictions_any(row):
    x = np.concatenate(row[model_dist_dict.keys()].values)
    x = np.unique(x)
    return x

# %%
def combine_predictions_major(row):
    x = np.concatenate(row[model_dist_dict.keys()].values)
    x, counts = np.unique(x, return_counts=True)
    
    ret_idx = counts > 1
    return x[ret_idx]

# %%
def combine_predictions_all(row):
    x = np.concatenate(row[model_dist_dict.keys()].values)

    x, counts = np.unique(x, return_counts=True)
    
    ret_idx = counts == 3
    return x[ret_idx]

# %%
def combine_predictions_major2(row):
    x = np.concatenate(row[model_dist_dict.keys()].values)
    x, counts = np.unique(x, return_counts=True)
    
    ret_idx = counts > 2
    return x[ret_idx]

# %% [markdown]
# ## get_cv(1件→2件むりやり)

# %%
def aggregate_distance(model_dist_dict, mode):
    ary = []
    
    for k, v in model_dist_dict.items():
        ary.append(model_dist_dict[k]["cosine_similarity"])
    
    ary = np.array(ary)
    
    if mode == "min":
        ary = ary.min(axis=0)
    if mode == "mean":
        ary = ary.mean(axis=0)
    if mode == "median":
        ary = np.median(ary, axis=0)
    if mode == "max":
        ary = ary.max(axis=0)

    return ary

# %%
df_result = []
for th in np.arange(0.4, 0.55, 0.01):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dist_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["cosine_similarity"],
                                            th,
                                            posting_id,
                                            pred_name=model_name,
                                            min_n=2,
                                            mode="max")
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    df["pred"] = df.apply(combine_predictions_major, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_major2, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    for mode in ["mean"]:
        f1score, precision, recall = get_cv(df,
                                            aggregate_distance(model_dist_dict, mode=mode),
                                            th,
                                            posting_id,
                                            pred_name=model_name,
                                            min_n=2,
                                            mode="max")
        print(f"<<aggregate_{mode}>> [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    f1score, precision, recall = get_cv(df,
                                        similarity_concat,
                                        th, 
                                        posting_id,
                                        pred_name=model_name,
                                        min_n=2,
                                        mode="max")
    print(f"<<emb_concat>> [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

    f1score, precision, recall = get_cv(df,
                                        similarity_mean,
                                        th, 
                                        posting_id,
                                        pred_name=model_name,
                                        min_n=2,
                                        mode="max")
    print(f"<<emb_mean>> [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
# Out:
# =========================================================
# THRESHOLD: 0.4
# model=distilbert [f1] 0.8339, [precision] 0.7935, [recall] 0.9484
# model=bert_seresnet [f1] 0.826, [precision] 0.7861, [recall] 0.9429
# model=bert2 [f1] 0.8596, [precision] 0.8369, [recall] 0.9398
# model=exp303 [f1] 0.8786, [precision] 0.8889, [recall] 0.9151
# <<<ensemble_MAJOR>>>: [f1] 0.8629, [precision] 0.8357, [recall] 0.952
# <<<ensemble_MAJOR>>>: [f1] 0.882, [precision] 0.8838, [recall] 0.9327
# <<aggregate_mean>> [f1] 0.8799, [precision] 0.8657, [recall] 0.9446
# <<emb_concat>> [f1] 0.8538, [precision] 0.8216, [recall] 0.9506
# <<emb_mean>> [f1] 0.8485, [precision] 0.8143, [recall] 0.9499
# =========================================================
# THRESHOLD: 0.41000000000000003
# model=distilbert [f1] 0.8426, [precision] 0.8086, [recall] 0.9451
# model=bert_seresnet [f1] 0.8351, [precision] 0.8022, [recall] 0.9391
# model=bert2 [f1] 0.8642, [precision] 0.8465, [recall] 0.9364
# model=exp303 [f1] 0.8788, [precision] 0.8936, [recall] 0.9104
# <<<ensemble_MAJOR>>>: [f1] 0.8686, [precision] 0.8466, [recall] 0.949
# <<<ensemble_MAJOR>>>: [f1] 0.8834, [precision] 0.8901, [recall] 0.928
# <<aggregate_mean>> [f1] 0.8832, [precision] 0.8739, [recall] 0.9407
# <<emb_concat>> [f1] 0.8608, [precision] 0.834, [recall] 0.9476
# <<emb_mean>> [f1] 0.8563, [precision] 0.828, [recall] 0.9472
# =========================================================
# THRESHOLD: 0.42000000000000004
# model=distilbert [f1] 0.8496, [precision] 0.8212, [recall] 0.9418
# model=bert_seresnet [f1] 0.8434, [precision] 0.8167, [recall] 0.9353
# model=bert2 [f1] 0.8684, [precision] 0.8558, [recall] 0.933
# model=exp303 [f1] 0.8789, [precision] 0.8983, [recall] 0.9058
# <<<ensemble_MAJOR>>>: [f1] 0.873, [precision] 0.8567, [recall] 0.945
# <<<ensemble_MAJOR>>>: [f1] 0.885, [precision] 0.8967, [recall] 0.9241
# <<aggregate_mean>> [f1] 0.8856, [precision] 0.8804, [recall] 0.9371
# <<emb_concat>> [f1] 0.8659, [precision] 0.8443, [recall] 0.9434
# <<emb_mean>> [f1] 0.862, [precision] 0.8393, [recall] 0.9436
# =========================================================
# THRESHOLD: 0.43000000000000005
# model=distilbert [f1] 0.8559, [precision] 0.8331, [recall] 0.9383
# model=bert_seresnet [f1] 0.8511, [precision] 0.8315, [recall] 0.9312
# model=bert2 [f1] 0.8726, [precision] 0.8648, [recall] 0.9298
# model=exp303 [f1] 0.879, [precision] 0.9026, [recall] 0.9015
# <<<ensemble_MAJOR>>>: [f1] 0.8776, [precision] 0.8661, [recall] 0.9422
# <<<ensemble_MAJOR>>>: [f1] 0.8865, [precision] 0.903, [recall] 0.9203
# <<aggregate_mean>> [f1] 0.8874, [precision] 0.8867, [recall] 0.9331
# <<emb_concat>> [f1] 0.8711, [precision] 0.8553, [recall] 0.9398
# <<emb_mean>> [f1] 0.8662, [precision] 0.8486, [recall] 0.9396
# =========================================================
# THRESHOLD: 0.44000000000000006
# model=distilbert [f1] 0.8611, [precision] 0.8437, [recall] 0.9348
# model=bert_seresnet [f1] 0.8566, [precision] 0.8427, [recall] 0.9272
# model=bert2 [f1] 0.8754, [precision] 0.8721, [recall] 0.9265
# model=exp303 [f1] 0.8782, [precision] 0.9067, [recall] 0.8961
# <<<ensemble_MAJOR>>>: [f1] 0.8804, [precision] 0.8734, [recall] 0.9386
# <<<ensemble_MAJOR>>>: [f1] 0.8874, [precision] 0.9084, [recall] 0.9164
# <<aggregate_mean>> [f1] 0.8892, [precision] 0.8928, [recall] 0.9296
# <<emb_concat>> [f1] 0.876, [precision] 0.8656, [recall] 0.9362
# <<emb_mean>> [f1] 0.8704, [precision] 0.8591, [recall] 0.9351
# =========================================================
# THRESHOLD: 0.45000000000000007
# model=distilbert [f1] 0.8655, [precision] 0.8533, [recall] 0.9309
# model=bert_seresnet [f1] 0.8611, [precision] 0.8526, [recall] 0.9237
# model=bert2 [f1] 0.878, [precision] 0.8794, [recall] 0.923
# model=exp303 [f1] 0.8772, [precision] 0.9105, [recall] 0.8905
# <<<ensemble_MAJOR>>>: [f1] 0.8829, [precision] 0.8801, [recall] 0.9352
# <<<ensemble_MAJOR>>>: [f1] 0.8878, [precision] 0.9141, [recall] 0.9114
# <<aggregate_mean>> [f1] 0.8901, [precision] 0.8982, [recall] 0.9255
# <<emb_concat>> [f1] 0.8787, [precision] 0.8735, [recall] 0.9324
# <<emb_mean>> [f1] 0.8736, [precision] 0.8674, [recall] 0.9309
# =========================================================
# THRESHOLD: 0.4600000000000001
# model=distilbert [f1] 0.8694, [precision] 0.862, [recall] 0.9274
# model=bert_seresnet [f1] 0.8646, [precision] 0.8616, [recall] 0.9194
# model=bert2 [f1] 0.8796, [precision] 0.8856, [recall] 0.9189
# model=exp303 [f1] 0.8756, [precision] 0.9142, [recall] 0.8846
# <<<ensemble_MAJOR>>>: [f1] 0.8853, [precision] 0.8868, [recall] 0.9318
# <<<ensemble_MAJOR>>>: [f1] 0.8871, [precision] 0.9186, [recall] 0.9061
# <<aggregate_mean>> [f1] 0.8907, [precision] 0.903, [recall] 0.9215
# <<emb_concat>> [f1] 0.8808, [precision] 0.8806, [recall] 0.9282
# <<emb_mean>> [f1] 0.877, [precision] 0.8753, [recall] 0.9276
# =========================================================
# THRESHOLD: 0.4700000000000001
# model=distilbert [f1] 0.8731, [precision] 0.871, [recall] 0.9239
# model=bert_seresnet [f1] 0.8675, [precision] 0.8693, [recall] 0.9158
# model=bert2 [f1] 0.8811, [precision] 0.892, [recall] 0.9147
# model=exp303 [f1] 0.8738, [precision] 0.9177, [recall] 0.879
# <<<ensemble_MAJOR>>>: [f1] 0.8878, [precision] 0.894, [recall] 0.9284
# <<<ensemble_MAJOR>>>: [f1] 0.8867, [precision] 0.9236, [recall] 0.9008
# <<aggregate_mean>> [f1] 0.8906, [precision] 0.9072, [recall] 0.9168
# <<emb_concat>> [f1] 0.8826, [precision] 0.8872, [recall] 0.9243
# <<emb_mean>> [f1] 0.8791, [precision] 0.8821, [recall] 0.9236
# =========================================================
# THRESHOLD: 0.4800000000000001
# model=distilbert [f1] 0.8756, [precision] 0.8783, [recall] 0.9202
# model=bert_seresnet [f1] 0.87, [precision] 0.8772, [recall] 0.9118
# model=bert2 [f1] 0.8808, [precision] 0.8959, [recall] 0.9101
# model=exp303 [f1] 0.8725, [precision] 0.921, [recall] 0.8737
# <<<ensemble_MAJOR>>>: [f1] 0.8893, [precision] 0.8994, [recall] 0.925
# <<<ensemble_MAJOR>>>: [f1] 0.8856, [precision] 0.9271, [recall] 0.8961
# <<aggregate_mean>> [f1] 0.8903, [precision] 0.9115, [recall] 0.9123
# <<emb_concat>> [f1] 0.8834, [precision] 0.8932, [recall] 0.9193
# <<emb_mean>> [f1] 0.8808, [precision] 0.8886, [recall] 0.9195
# =========================================================
# THRESHOLD: 0.4900000000000001
# model=distilbert [f1] 0.8771, [precision] 0.8845, [recall] 0.9159
# model=bert_seresnet [f1] 0.8717, [precision] 0.8836, [recall] 0.9079
# model=bert2 [f1] 0.881, [precision] 0.9007, [recall] 0.9055
# model=exp303 [f1] 0.8703, [precision] 0.9234, [recall] 0.8681
# <<<ensemble_MAJOR>>>: [f1] 0.8904, [precision] 0.9051, [recall] 0.9211
# <<<ensemble_MAJOR>>>: [f1] 0.8837, [precision] 0.9295, [recall] 0.8909
# <<aggregate_mean>> [f1] 0.889, [precision] 0.915, [recall] 0.9071
# <<emb_concat>> [f1] 0.8845, [precision] 0.8979, [recall] 0.9161
# <<emb_mean>> [f1] 0.882, [precision] 0.895, [recall] 0.9148
# =========================================================
# THRESHOLD: 0.5000000000000001
# model=distilbert [f1] 0.8777, [precision] 0.8903, [recall] 0.9108
# model=bert_seresnet [f1] 0.8731, [precision] 0.8902, [recall] 0.9034
# model=bert2 [f1] 0.8805, [precision] 0.9041, [recall] 0.9012
# model=exp303 [f1] 0.8682, [precision] 0.9261, [recall] 0.8628
# <<<ensemble_MAJOR>>>: [f1] 0.8904, [precision] 0.9097, [recall] 0.9165
# <<<ensemble_MAJOR>>>: [f1] 0.8816, [precision] 0.9325, [recall] 0.8852
# <<aggregate_mean>> [f1] 0.8882, [precision] 0.9182, [recall] 0.9026
# <<emb_concat>> [f1] 0.8847, [precision] 0.903, [recall] 0.9113
# <<emb_mean>> [f1] 0.8827, [precision] 0.9003, [recall] 0.9106
# =========================================================
# THRESHOLD: 0.5100000000000001
# model=distilbert [f1] 0.8786, [precision] 0.8962, [recall] 0.9062
# model=bert_seresnet [f1] 0.8741, [precision] 0.8966, [recall] 0.8989
# model=bert2 [f1] 0.8805, [precision] 0.9081, [recall] 0.8975
# model=exp303 [f1] 0.8657, [precision] 0.9289, [recall] 0.8564
# <<<ensemble_MAJOR>>>: [f1] 0.89, [precision] 0.9137, [recall] 0.9122
# <<<ensemble_MAJOR>>>: [f1] 0.8797, [precision] 0.9358, [recall] 0.8796
# <<aggregate_mean>> [f1] 0.8871, [precision] 0.9217, [recall] 0.898
# <<emb_concat>> [f1] 0.8849, [precision] 0.9077, [recall] 0.9067
# <<emb_mean>> [f1] 0.8823, [precision] 0.9044, [recall] 0.9058
# =========================================================
# THRESHOLD: 0.5200000000000001
# model=distilbert [f1] 0.8788, [precision] 0.9005, [recall] 0.9022
# model=bert_seresnet [f1] 0.8747, [precision] 0.9022, [recall] 0.8941
# model=bert2 [f1] 0.8789, [precision] 0.9114, [recall] 0.8916
# model=exp303 [f1] 0.8622, [precision] 0.9311, [recall] 0.8491
# <<<ensemble_MAJOR>>>: [f1] 0.8894, [precision] 0.9177, [recall] 0.9073
# <<<ensemble_MAJOR>>>: [f1] 0.8774, [precision] 0.9383, [recall] 0.8741
# <<aggregate_mean>> [f1] 0.8848, [precision] 0.9243, [recall] 0.892
# <<emb_concat>> [f1] 0.8839, [precision] 0.911, [recall] 0.9017
# <<emb_mean>> [f1] 0.8828, [precision] 0.9091, [recall] 0.9017
# =========================================================
# THRESHOLD: 0.5300000000000001
# model=distilbert [f1] 0.8787, [precision] 0.905, [recall] 0.8978
# model=bert_seresnet [f1] 0.8737, [precision] 0.9059, [recall] 0.8892
# model=bert2 [f1] 0.8777, [precision] 0.9148, [recall] 0.8864
# model=exp303 [f1] 0.8594, [precision] 0.9336, [recall] 0.8429
# <<<ensemble_MAJOR>>>: [f1] 0.8878, [precision] 0.9208, [recall] 0.9019
# <<<ensemble_MAJOR>>>: [f1] 0.8753, [precision] 0.941, [recall] 0.8689
# <<aggregate_mean>> [f1] 0.8826, [precision] 0.9266, [recall] 0.8866
# <<emb_concat>> [f1] 0.8833, [precision] 0.9149, [recall] 0.8972
# <<emb_mean>> [f1] 0.8815, [precision] 0.912, [recall] 0.8971
# =========================================================
# THRESHOLD: 0.5400000000000001
# model=distilbert [f1] 0.8787, [precision] 0.9092, [recall] 0.8935
# model=bert_seresnet [f1] 0.8733, [precision] 0.9099, [recall] 0.8848
# model=bert2 [f1] 0.8764, [precision] 0.918, [recall] 0.8817
# model=exp303 [f1] 0.8562, [precision] 0.9355, [recall] 0.8366
# <<<ensemble_MAJOR>>>: [f1] 0.8865, [precision] 0.9237, [recall] 0.8975
# <<<ensemble_MAJOR>>>: [f1] 0.8733, [precision] 0.9434, [recall] 0.8638
# <<aggregate_mean>> [f1] 0.881, [precision] 0.9292, [recall] 0.8818
# <<emb_concat>> [f1] 0.8819, [precision] 0.9179, [recall] 0.8927
# <<emb_mean>> [f1] 0.8803, [precision] 0.9156, [recall] 0.8919
# =========================================================
# THRESHOLD: 0.5500000000000002
# model=distilbert [f1] 0.8776, [precision] 0.9125, [recall] 0.8889
# model=bert_seresnet [f1] 0.8716, [precision] 0.9128, [recall] 0.8791
# model=bert2 [f1] 0.8743, [precision] 0.9211, [recall] 0.8757
# model=exp303 [f1] 0.8532, [precision] 0.9376, [recall] 0.8306
# <<<ensemble_MAJOR>>>: [f1] 0.8843, [precision] 0.9261, [recall] 0.8918
# <<<ensemble_MAJOR>>>: [f1] 0.8709, [precision] 0.9459, [recall] 0.8581
# <<aggregate_mean>> [f1] 0.8785, [precision] 0.9314, [recall] 0.8762
# <<emb_concat>> [f1] 0.88, [precision] 0.9202, [recall] 0.8877
# <<emb_mean>> [f1] 0.8799, [precision] 0.9193, [recall] 0.8881

# %%
df_result = []
for th in np.arange(0.55, 0.7, 0.05):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dist_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["cosine_similarity"],
                                            th,
                                            posting_id,
                                            pred_name=model_name,
                                            min_n=2,
                                            mode="max")
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

# %%
import matplotlib.pyplot as plt

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
    plt.legend()
    plt.ylim(0, 5e+6)
    plt.title(model_name)
    plt.show()

plt.figure(figsize=(20, 2))
plt.hist(aggregate_distance(model_dist_dict, mode="mean").flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
plt.legend()
plt.ylim(0, 5e+6)
plt.title("mean")
plt.show()

plt.figure(figsize=(20, 2))
plt.hist(aggregate_distance(model_dist_dict, mode="median").flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
plt.legend()
plt.ylim(0, 5e+6)
plt.title("median")
plt.show()

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=71, range=(0.3, 1), label=model_name)
    plt.legend()
    plt.ylim(0, 20000)
    plt.title(model_name)
    plt.show()

plt.figure(figsize=(20, 2))
plt.hist(aggregate_distance(model_dist_dict, mode="mean").flatten(), alpha=0.2, bins=71, range=(0.3, 1), label=model_name)
plt.legend()
plt.ylim(0, 20000)
plt.title("mean")
plt.show()

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=71, range=(0.4, 1), label=model_name)
    plt.legend()
    plt.ylim(0, 2000)
    plt.title(model_name)
    plt.hlines(500, xmin=0.4, xmax=1, color="red", alpha=0.3)
    plt.show()

plt.figure(figsize=(20, 2))
plt.hist(aggregate_distance(model_dist_dict, mode="mean").flatten(), alpha=0.2, bins=71, range=(0.4, 1), label=model_name)
plt.legend()
plt.ylim(0, 2000)
plt.hlines(500, xmin=0.4, xmax=1, color="red", alpha=0.3)
plt.title("mean")
plt.show()

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
    plt.legend()
    plt.ylim(0, 5e+6)
    plt.title(model_name)
    plt.show()

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
    plt.legend()
    plt.yscale("log")
    plt.title(model_name)
    plt.show()

# %%
for model_name in model_dist_dict.keys():
    plt.figure(figsize=(20, 2))
    if model_name == "exp303":
        plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten()*0.52/0.42, alpha=0.2, bins=199, range=(-1, 1), label=model_name)
    else:
        plt.hist(model_dist_dict[model_name]["cosine_similarity"].flatten(), alpha=0.2, bins=199, range=(-1, 1), label=model_name)
    plt.legend()
    plt.ylim(0, 5e+6)
    plt.title(model_name)
    plt.show()
