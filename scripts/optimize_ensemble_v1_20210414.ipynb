# %% [markdown]
# # ensembleを試したい
# * embeddingデータをとるのを忘れてしまった。。。ので、とりあえずはdistances, indicesから最適アンサンブルの閾値を探す。。。

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
import glob
import tqdm

# %%
df = pd.read_csv("../input/shopee-product-matching/train_fold.csv")
df = df[df["fold"] == 0]
tmp = df.groupby('label_group').posting_id.agg('unique').to_dict()
df['target'] = df.label_group.map(tmp)

# %%
posting_id = df["posting_id"].values

# %%
def get_cv(df, similarity_matrix, threshold, posting_id, indices=None, pred_name="pred", min_n=2):
    preds = []
    for k in range(len(df)):
        IDX = np.where(similarity_matrix[k, ] < threshold)[0]
        if indices is None:
            pred = posting_id[IDX]
        else:
            if len(IDX) < min_n:
                IDX = np.argsort(similarity_matrix[k, ])[:min_n]
            idx = indices[k, IDX]
            pred = posting_id[idx]
        preds.append(pred)
    
    df[pred_name] = preds
    f1score, precision, recall = calc_cv(df, col_name=pred_name)
    return f1score, precision, recall

# %%
def calc_cv(df, col_name):
    tmp = df.groupby('label_group').posting_id.agg('unique').to_dict()
    df['target'] = df.label_group.map(tmp)
    df['f1'] = df.apply(get_f1(col_name),axis=1)
    df["precision"] = df.apply(get_precision(col_name), axis=1)
    df["recall"] = df.apply(get_recall(col_name), axis=1)
    return df["f1"].mean(), df["precision"].mean(), df["recall"].mean()

def get_f1(col):
    def f1score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        return 2*n / (len(row.target)+len(row[col]))
    return f1score

def get_precision(col):
    def precision_score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        if len(row[col]) == 0:
            return 0
        else:
            return n / len(row[col])
    return precision_score

def get_recall(col):
    def recall_score(row):
        n = len( np.intersect1d(row.target,row[col]) )
        return n / len(row.target)
    return recall_score

# %%
def get_best_epochs(model_path, early_stopping_round=3):
    file_len = len(glob.glob(f"{model_path}/indices_epoch*.npy"))
    return file_len - early_stopping_round - 1 # epoch は0はじまりなのでさらに1ひく


model_dict = {
    "xlm_roberta_base": "../output/exp020/20210414065420", # CV: 0.847
    "distilbert_base": "../output/exp020/20210414091557", # CV: 0.856
    "bert_base": "../output/exp020/20210414113059" # CV: 0.854
}

model_dist_dict = {}
    
for k, path in model_dict.items():
    best_epochs = get_best_epochs(path)
    
    model_dist_dict[k] = {
        "distances": np.load(f"{path}/distances_epoch{best_epochs}.npy"),
        "indices": np.load(f"{path}/indices_epoch{best_epochs}.npy")
    }

# %%
def combine_predictions_any(row):
    x = np.concatenate([row['xlm_roberta_base'], row['distilbert_base'], row["bert_base"]])
    x = np.unique(x)
    return x

# %%
def combine_predictions_major(row):
    x = np.concatenate([row['xlm_roberta_base'], row['distilbert_base'], row["bert_base"]])
    x, counts = np.unique(x, return_counts=True)
    
    ret_idx = counts > 1
    return x[ret_idx]

# %%
def combine_predictions_all(row):
    x = np.concatenate([row['xlm_roberta_base'], row['distilbert_base'], row["bert_base"]])
    x, counts = np.unique(x, return_counts=True)
    
    ret_idx = counts == 3
    return x[ret_idx]

# %% [markdown]
# ## get_cv (normal)

# %%
df_result = []
for th in np.arange(15, 22, 0.5):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["distances"],
                                            th,
                                            posting_id,
                                            model_dist_dict[model_name]["indices"],
                                            pred_name=model_name,
                                            min_n=1)
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

    df["pred"] = df.apply(combine_predictions_any, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ANY>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_major, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_all, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ALL>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
# Out:
# =========================================================
# THRESHOLD: 15.0
# model=xlm_roberta_base [f1] 0.7771, [precision] 0.975, [recall] 0.7084
# model=distilbert_base [f1] 0.7689, [precision] 0.9785, [recall] 0.6955
# model=bert_base [f1] 0.7657, [precision] 0.9787, [recall] 0.6888
# <<<ensemble_ANY>>>: [f1] 0.8081, [precision] 0.9698, [recall] 0.7537
# <<<ensemble_MAJOR>>>: [f1] 0.7718, [precision] 0.9789, [recall] 0.6991
# <<<ensemble_ALL>>>: [f1] 0.7306, [precision] 0.9848, [recall] 0.6399
# =========================================================
# THRESHOLD: 15.5
# model=xlm_roberta_base [f1] 0.792, [precision] 0.9713, [recall] 0.7308
# model=distilbert_base [f1] 0.7855, [precision] 0.9741, [recall] 0.7204
# model=bert_base [f1] 0.7848, [precision] 0.9752, [recall] 0.7174
# <<<ensemble_ANY>>>: [f1] 0.8225, [precision] 0.9642, [recall] 0.7775
# <<<ensemble_MAJOR>>>: [f1] 0.7889, [precision] 0.9759, [recall] 0.7243
# <<<ensemble_ALL>>>: [f1] 0.7496, [precision] 0.982, [recall] 0.6668
# =========================================================
# THRESHOLD: 16.0
# model=xlm_roberta_base [f1] 0.8036, [precision] 0.9655, [recall] 0.7508
# model=distilbert_base [f1] 0.7989, [precision] 0.9685, [recall] 0.7422
# model=bert_base [f1] 0.8012, [precision] 0.9694, [recall] 0.7432
# <<<ensemble_ANY>>>: [f1] 0.8346, [precision] 0.9561, [recall] 0.8001
# <<<ensemble_MAJOR>>>: [f1] 0.8023, [precision] 0.9703, [recall] 0.7459
# <<<ensemble_ALL>>>: [f1] 0.7657, [precision] 0.9788, [recall] 0.6901
# =========================================================
# THRESHOLD: 16.5
# model=xlm_roberta_base [f1] 0.8154, [precision] 0.9587, [recall] 0.772
# model=distilbert_base [f1] 0.813, [precision] 0.9627, [recall] 0.7658
# model=bert_base [f1] 0.8145, [precision] 0.9627, [recall] 0.7664
# <<<ensemble_ANY>>>: [f1] 0.8451, [precision] 0.9461, [recall] 0.8227
# <<<ensemble_MAJOR>>>: [f1] 0.8153, [precision] 0.9645, [recall] 0.768
# <<<ensemble_ALL>>>: [f1] 0.7815, [precision] 0.9759, [recall] 0.7134
# =========================================================
# THRESHOLD: 17.0
# model=xlm_roberta_base [f1] 0.8263, [precision] 0.9503, [recall] 0.7928
# model=distilbert_base [f1] 0.8253, [precision] 0.9553, [recall] 0.7889
# model=bert_base [f1] 0.8277, [precision] 0.9549, [recall] 0.7909
# <<<ensemble_ANY>>>: [f1] 0.8525, [precision] 0.9343, [recall] 0.8431
# <<<ensemble_MAJOR>>>: [f1] 0.8286, [precision] 0.9581, [recall] 0.791
# <<<ensemble_ALL>>>: [f1] 0.7972, [precision] 0.9711, [recall] 0.7385
# =========================================================
# THRESHOLD: 17.5
# model=xlm_roberta_base [f1] 0.8394, [precision] 0.9405, [recall] 0.8191
# model=distilbert_base [f1] 0.8369, [precision] 0.9471, [recall] 0.8107
# model=bert_base [f1] 0.8382, [precision] 0.9459, [recall] 0.8128
# <<<ensemble_ANY>>>: [f1] 0.8604, [precision] 0.9202, [recall] 0.8662
# <<<ensemble_MAJOR>>>: [f1] 0.8422, [precision] 0.951, [recall] 0.8151
# <<<ensemble_ALL>>>: [f1] 0.8113, [precision] 0.9656, [recall] 0.7612
# =========================================================
# THRESHOLD: 18.0
# model=xlm_roberta_base [f1] 0.8456, [precision] 0.9239, [recall] 0.8414
# model=distilbert_base [f1] 0.846, [precision] 0.9374, [recall] 0.8314
# model=bert_base [f1] 0.8473, [precision] 0.9351, [recall] 0.8351
# <<<ensemble_ANY>>>: [f1] 0.8605, [precision] 0.9001, [recall] 0.8846
# <<<ensemble_MAJOR>>>: [f1] 0.8532, [precision] 0.9413, [recall] 0.8384
# <<<ensemble_ALL>>>: [f1] 0.8251, [precision] 0.9599, [recall] 0.785
# =========================================================
# THRESHOLD: 18.5
# model=xlm_roberta_base [f1] 0.8465, [precision] 0.903, [recall] 0.8619
# model=distilbert_base [f1] 0.8526, [precision] 0.9251, [recall] 0.8517
# model=bert_base [f1] 0.8527, [precision] 0.9219, [recall] 0.855
# <<<ensemble_ANY>>>: [f1] 0.8538, [precision] 0.8728, [recall] 0.9019
# <<<ensemble_MAJOR>>>: [f1] 0.8613, [precision] 0.9306, [recall] 0.8597
# <<<ensemble_ALL>>>: [f1] 0.8376, [precision] 0.9538, [recall] 0.8071
# =========================================================
# THRESHOLD: 19.0
# model=xlm_roberta_base [f1] 0.8393, [precision] 0.8724, [recall] 0.8801
# model=distilbert_base [f1] 0.8555, [precision] 0.9072, [recall] 0.872
# model=bert_base [f1] 0.853, [precision] 0.9008, [recall] 0.8737
# <<<ensemble_ANY>>>: [f1] 0.8372, [precision] 0.833, [recall] 0.9178
# <<<ensemble_MAJOR>>>: [f1] 0.8655, [precision] 0.9152, [recall] 0.8791
# <<<ensemble_ALL>>>: [f1] 0.8484, [precision] 0.9451, [recall] 0.829
# =========================================================
# THRESHOLD: 19.5
# model=xlm_roberta_base [f1] 0.8164, [precision] 0.8263, [recall] 0.895
# model=distilbert_base [f1] 0.8492, [precision] 0.8797, [recall] 0.889
# model=bert_base [f1] 0.8477, [precision] 0.8732, [recall] 0.8926
# <<<ensemble_ANY>>>: [f1] 0.8027, [precision] 0.7741, [recall] 0.9317
# <<<ensemble_MAJOR>>>: [f1] 0.8621, [precision] 0.8934, [recall] 0.8947
# <<<ensemble_ALL>>>: [f1] 0.8575, [precision] 0.9352, [recall] 0.8502
# =========================================================
# THRESHOLD: 20.0
# model=xlm_roberta_base [f1] 0.7754, [precision] 0.7603, [recall] 0.9087
# model=distilbert_base [f1] 0.8325, [precision] 0.8414, [recall] 0.9044
# model=bert_base [f1] 0.8288, [precision] 0.8325, [recall] 0.906
# <<<ensemble_ANY>>>: [f1] 0.7459, [precision] 0.6942, [recall] 0.9424
# <<<ensemble_MAJOR>>>: [f1] 0.8523, [precision] 0.8645, [recall] 0.9087
# <<<ensemble_ALL>>>: [f1] 0.8603, [precision] 0.9195, [recall] 0.868
# =========================================================
# THRESHOLD: 20.5
# model=xlm_roberta_base [f1] 0.7168, [precision] 0.6773, [recall] 0.9236
# model=distilbert_base [f1] 0.8026, [precision] 0.7893, [recall] 0.9182
# model=bert_base [f1] 0.7966, [precision] 0.7768, [recall] 0.9193
# <<<ensemble_ANY>>>: [f1] 0.667, [precision] 0.5948, [recall] 0.9521
# <<<ensemble_MAJOR>>>: [f1] 0.8335, [precision] 0.8238, [recall] 0.9243
# <<<ensemble_ALL>>>: [f1] 0.8581, [precision] 0.8979, [recall] 0.8847
# =========================================================
# THRESHOLD: 21.0
# model=xlm_roberta_base [f1] 0.6366, [precision] 0.5781, [recall] 0.9352
# model=distilbert_base [f1] 0.7519, [precision] 0.7155, [recall] 0.9307
# model=bert_base [f1] 0.7424, [precision] 0.6984, [recall] 0.9311
# <<<ensemble_ANY>>>: [f1] 0.5618, [precision] 0.476, [recall] 0.9619
# <<<ensemble_MAJOR>>>: [f1] 0.7989, [precision] 0.7672, [recall] 0.9362
# <<<ensemble_ALL>>>: [f1] 0.8511, [precision] 0.8721, [recall] 0.8989
# =========================================================
# THRESHOLD: 21.5
# model=xlm_roberta_base [f1] 0.5389, [precision] 0.4682, [recall] 0.9467
# model=distilbert_base [f1] 0.6806, [precision] 0.6233, [recall] 0.9419
# model=bert_base [f1] 0.6643, [precision] 0.5989, [recall] 0.9427
# <<<ensemble_ANY>>>: [f1] 0.443, [precision] 0.354, [recall] 0.9708
# <<<ensemble_MAJOR>>>: [f1] 0.7429, [precision] 0.6885, [recall] 0.9474
# <<<ensemble_ALL>>>: [f1] 0.8331, [precision] 0.8322, [recall] 0.9131

# %% [markdown]
# ## get_cv(1件→2件むりやり)

# %%
df_result = []
for th in np.arange(15, 22, 0.5):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["distances"],
                                            th,
                                            posting_id,
                                            model_dist_dict[model_name]["indices"],
                                            pred_name=model_name,
                                            min_n=2)
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

    df["pred"] = df.apply(combine_predictions_any, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ANY>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_major, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_all, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ALL>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
# Out:
# =========================================================
# THRESHOLD: 15.0
# model=xlm_roberta_base [f1] 0.8278, [precision] 0.9366, [recall] 0.7889
# model=distilbert_base [f1] 0.8258, [precision] 0.9448, [recall] 0.783
# model=bert_base [f1] 0.8235, [precision] 0.9429, [recall] 0.778
# <<<ensemble_ANY>>>: [f1] 0.8497, [precision] 0.9204, [recall] 0.8363
# <<<ensemble_MAJOR>>>: [f1] 0.8313, [precision] 0.9622, [recall] 0.7844
# <<<ensemble_ALL>>>: [f1] 0.794, [precision] 0.979, [recall] 0.7292
# =========================================================
# THRESHOLD: 15.5
# model=xlm_roberta_base [f1] 0.836, [precision] 0.9343, [recall] 0.8023
# model=distilbert_base [f1] 0.8343, [precision] 0.9419, [recall] 0.7967
# model=bert_base [f1] 0.8327, [precision] 0.9405, [recall] 0.7931
# <<<ensemble_ANY>>>: [f1] 0.8564, [precision] 0.9169, [recall] 0.8492
# <<<ensemble_MAJOR>>>: [f1] 0.8408, [precision] 0.9598, [recall] 0.7993
# <<<ensemble_ALL>>>: [f1] 0.8038, [precision] 0.9769, [recall] 0.7437
# =========================================================
# THRESHOLD: 16.0
# model=xlm_roberta_base [f1] 0.8428, [precision] 0.9303, [recall] 0.8154
# model=distilbert_base [f1] 0.841, [precision] 0.9377, [recall] 0.8089
# model=bert_base [f1] 0.8411, [precision] 0.9373, [recall] 0.8074
# <<<ensemble_ANY>>>: [f1] 0.8616, [precision] 0.9113, [recall] 0.8615
# <<<ensemble_MAJOR>>>: [f1] 0.8483, [precision] 0.9564, [recall] 0.8123
# <<<ensemble_ALL>>>: [f1] 0.8133, [precision] 0.974, [recall] 0.7579
# =========================================================
# THRESHOLD: 16.5
# model=xlm_roberta_base [f1] 0.8487, [precision] 0.9249, [recall] 0.8287
# model=distilbert_base [f1] 0.8486, [precision] 0.9333, [recall] 0.8236
# model=bert_base [f1] 0.8484, [precision] 0.9318, [recall] 0.8226
# <<<ensemble_ANY>>>: [f1] 0.8654, [precision] 0.9034, [recall] 0.8746
# <<<ensemble_MAJOR>>>: [f1] 0.8548, [precision] 0.9514, [recall] 0.8257
# <<<ensemble_ALL>>>: [f1] 0.8245, [precision] 0.9714, [recall] 0.7745
# =========================================================
# THRESHOLD: 17.0
# model=xlm_roberta_base [f1] 0.8536, [precision] 0.9184, [recall] 0.841
# model=distilbert_base [f1] 0.8542, [precision] 0.9271, [recall] 0.8376
# model=bert_base [f1] 0.8547, [precision] 0.9255, [recall] 0.8375
# <<<ensemble_ANY>>>: [f1] 0.8667, [precision] 0.8939, [recall] 0.8859
# <<<ensemble_MAJOR>>>: [f1] 0.862, [precision] 0.9462, [recall] 0.8403
# <<<ensemble_ALL>>>: [f1] 0.8334, [precision] 0.9667, [recall] 0.7898
# =========================================================
# THRESHOLD: 17.5
# model=xlm_roberta_base [f1] 0.8593, [precision] 0.9103, [recall] 0.8568
# model=distilbert_base [f1] 0.8601, [precision] 0.9205, [recall] 0.8514
# model=bert_base [f1] 0.8598, [precision] 0.9183, [recall] 0.8517
# <<<ensemble_ANY>>>: [f1] 0.8682, [precision] 0.8828, [recall] 0.8993
# <<<ensemble_MAJOR>>>: [f1] 0.8688, [precision] 0.9398, [recall] 0.8553
# <<<ensemble_ALL>>>: [f1] 0.8423, [precision] 0.9619, [recall] 0.8053
# =========================================================
# THRESHOLD: 18.0
# model=xlm_roberta_base [f1] 0.8594, [precision] 0.8961, [recall] 0.8701
# model=distilbert_base [f1] 0.8638, [precision] 0.9125, [recall] 0.8645
# model=bert_base [f1] 0.8627, [precision] 0.9086, [recall] 0.8654
# <<<ensemble_ANY>>>: [f1] 0.8632, [precision] 0.8658, [recall] 0.9091
# <<<ensemble_MAJOR>>>: [f1] 0.8738, [precision] 0.9314, [recall] 0.8704
# <<<ensemble_ALL>>>: [f1] 0.8499, [precision] 0.9561, [recall] 0.8205
# =========================================================
# THRESHOLD: 18.5
# model=xlm_roberta_base [f1] 0.8555, [precision] 0.8772, [recall] 0.8837
# model=distilbert_base [f1] 0.8657, [precision] 0.9016, [recall] 0.878
# model=bert_base [f1] 0.8634, [precision] 0.8969, [recall] 0.8787
# <<<ensemble_ANY>>>: [f1] 0.853, [precision] 0.8413, [recall] 0.9204
# <<<ensemble_MAJOR>>>: [f1] 0.8764, [precision] 0.9215, [recall] 0.884
# <<<ensemble_ALL>>>: [f1] 0.8575, [precision] 0.9503, [recall] 0.8359
# =========================================================
# THRESHOLD: 19.0
# model=xlm_roberta_base [f1] 0.8441, [precision] 0.8497, [recall] 0.8952
# model=distilbert_base [f1] 0.8641, [precision] 0.8862, [recall] 0.8916
# model=bert_base [f1] 0.8603, [precision] 0.8793, [recall] 0.8914
# <<<ensemble_ANY>>>: [f1] 0.8337, [precision] 0.8061, [recall] 0.9306
# <<<ensemble_MAJOR>>>: [f1] 0.8762, [precision] 0.9081, [recall] 0.8964
# <<<ensemble_ALL>>>: [f1] 0.8637, [precision] 0.9419, [recall] 0.8512
# =========================================================
# THRESHOLD: 19.5
# model=xlm_roberta_base [f1] 0.8196, [precision] 0.8073, [recall] 0.9066
# model=distilbert_base [f1] 0.8548, [precision] 0.8614, [recall] 0.9038
# model=bert_base [f1] 0.8518, [precision] 0.8547, [recall] 0.9049
# <<<ensemble_ANY>>>: [f1] 0.7991, [precision] 0.7535, [recall] 0.9409
# <<<ensemble_MAJOR>>>: [f1] 0.8697, [precision] 0.8867, [recall] 0.9077
# <<<ensemble_ALL>>>: [f1] 0.8686, [precision] 0.9323, [recall] 0.8668
# =========================================================
# THRESHOLD: 20.0
# model=xlm_roberta_base [f1] 0.7776, [precision] 0.7463, [recall] 0.9169
# model=distilbert_base [f1] 0.8352, [precision] 0.825, [recall] 0.9143
# model=bert_base [f1] 0.8315, [precision] 0.8172, [recall] 0.9156
# <<<ensemble_ANY>>>: [f1] 0.7423, [precision] 0.6789, [recall] 0.9483
# <<<ensemble_MAJOR>>>: [f1] 0.8579, [precision] 0.8593, [recall] 0.9184
# <<<ensemble_ALL>>>: [f1] 0.8684, [precision] 0.917, [recall] 0.8801
# =========================================================
# THRESHOLD: 20.5
# model=xlm_roberta_base [f1] 0.7171, [precision] 0.6667, [recall] 0.928
# model=distilbert_base [f1] 0.8044, [precision] 0.7759, [recall] 0.9259
# model=bert_base [f1] 0.7976, [precision] 0.7646, [recall] 0.9252
# <<<ensemble_ANY>>>: [f1] 0.6644, [precision] 0.5845, [recall] 0.9564
# <<<ensemble_MAJOR>>>: [f1] 0.8363, [precision] 0.8194, [recall] 0.93
# <<<ensemble_ALL>>>: [f1] 0.8634, [precision] 0.8958, [recall] 0.8927
# =========================================================
# THRESHOLD: 21.0
# model=xlm_roberta_base [f1] 0.6364, [precision] 0.5706, [recall] 0.9377
# model=distilbert_base [f1] 0.7526, [precision] 0.7053, [recall] 0.9357
# model=bert_base [f1] 0.7429, [precision] 0.6896, [recall] 0.9352
# <<<ensemble_ANY>>>: [f1] 0.5597, [precision] 0.4691, [recall] 0.9645
# <<<ensemble_MAJOR>>>: [f1] 0.8006, [precision] 0.7644, [recall] 0.9398
# <<<ensemble_ALL>>>: [f1] 0.8545, [precision] 0.8704, [recall] 0.9043
# =========================================================
# THRESHOLD: 21.5
# model=xlm_roberta_base [f1] 0.5389, [precision] 0.4632, [recall] 0.9486
# model=distilbert_base [f1] 0.6807, [precision] 0.6164, [recall] 0.945
# model=bert_base [f1] 0.6641, [precision] 0.5925, [recall] 0.9449
# <<<ensemble_ANY>>>: [f1] 0.4416, [precision] 0.35, [recall] 0.9723
# <<<ensemble_MAJOR>>>: [f1] 0.7437, [precision] 0.686, [recall] 0.9498
# <<<ensemble_ALL>>>: [f1] 0.8353, [precision] 0.8314, [recall] 0.9165

# %% [markdown]
# # get_cv(1件→3件むりやり)

# %%
df_result = []
for th in np.arange(15, 22, 0.5):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["distances"],
                                            th,
                                            posting_id,
                                            model_dist_dict[model_name]["indices"],
                                            pred_name=model_name,
                                            min_n=3)
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

    df["pred"] = df.apply(combine_predictions_any, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ANY>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_major, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_all, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ALL>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
# Out:
# =========================================================
# THRESHOLD: 15.0
# model=xlm_roberta_base [f1] 0.78, [precision] 0.8078, [recall] 0.8277
# model=distilbert_base [f1] 0.7796, [precision] 0.815, [recall] 0.8243
# model=bert_base [f1] 0.7781, [precision] 0.8127, [recall] 0.821
# <<<ensemble_ANY>>>: [f1] 0.732, [precision] 0.7177, [recall] 0.8726
# <<<ensemble_MAJOR>>>: [f1] 0.8348, [precision] 0.9131, [recall] 0.8267
# <<<ensemble_ALL>>>: [f1] 0.819, [precision] 0.9611, [recall] 0.7737
# =========================================================
# THRESHOLD: 15.5
# model=xlm_roberta_base [f1] 0.7859, [precision] 0.8065, [recall] 0.8372
# model=distilbert_base [f1] 0.7853, [precision] 0.813, [recall] 0.8338
# model=bert_base [f1] 0.7848, [precision] 0.8111, [recall] 0.8321
# <<<ensemble_ANY>>>: [f1] 0.7369, [precision] 0.7156, [recall] 0.8816
# <<<ensemble_MAJOR>>>: [f1] 0.8413, [precision] 0.9115, [recall] 0.8373
# <<<ensemble_ALL>>>: [f1] 0.8261, [precision] 0.9596, [recall] 0.7842
# =========================================================
# THRESHOLD: 16.0
# model=xlm_roberta_base [f1] 0.7904, [precision] 0.8041, [recall] 0.8456
# model=distilbert_base [f1] 0.7903, [precision] 0.8104, [recall] 0.8427
# model=bert_base [f1] 0.7908, [precision] 0.8092, [recall] 0.8425
# <<<ensemble_ANY>>>: [f1] 0.7406, [precision] 0.7127, [recall] 0.8897
# <<<ensemble_MAJOR>>>: [f1] 0.8465, [precision] 0.9091, [recall] 0.8463
# <<<ensemble_ALL>>>: [f1] 0.833, [precision] 0.9572, [recall] 0.7948
# =========================================================
# THRESHOLD: 16.5
# model=xlm_roberta_base [f1] 0.7949, [precision] 0.8011, [recall] 0.8551
# model=distilbert_base [f1] 0.7958, [precision] 0.8076, [recall] 0.8532
# model=bert_base [f1] 0.7964, [precision] 0.8059, [recall] 0.8536
# <<<ensemble_ANY>>>: [f1] 0.744, [precision] 0.7084, [recall] 0.8992
# <<<ensemble_MAJOR>>>: [f1] 0.8515, [precision] 0.9063, [recall] 0.8562
# <<<ensemble_ALL>>>: [f1] 0.8403, [precision] 0.9546, [recall] 0.8065
# =========================================================
# THRESHOLD: 17.0
# model=xlm_roberta_base [f1] 0.7991, [precision] 0.7972, [recall] 0.8648
# model=distilbert_base [f1] 0.8005, [precision] 0.8043, [recall] 0.8637
# model=bert_base [f1] 0.8012, [precision] 0.8021, [recall] 0.8643
# <<<ensemble_ANY>>>: [f1] 0.7464, [precision] 0.7034, [recall] 0.9079
# <<<ensemble_MAJOR>>>: [f1] 0.8563, [precision] 0.9026, [recall] 0.8665
# <<<ensemble_ALL>>>: [f1] 0.8472, [precision] 0.9516, [recall] 0.8183
# =========================================================
# THRESHOLD: 17.5
# model=xlm_roberta_base [f1] 0.8032, [precision] 0.7918, [recall] 0.8762
# model=distilbert_base [f1] 0.8049, [precision] 0.8001, [recall] 0.8739
# model=bert_base [f1] 0.8054, [precision] 0.798, [recall] 0.8747
# <<<ensemble_ANY>>>: [f1] 0.7478, [precision] 0.6969, [recall] 0.9171
# <<<ensemble_MAJOR>>>: [f1] 0.8615, [precision] 0.8985, [recall] 0.8779
# <<<ensemble_ALL>>>: [f1] 0.8536, [precision] 0.948, [recall] 0.8299
# =========================================================
# THRESHOLD: 18.0
# model=xlm_roberta_base [f1] 0.8043, [precision] 0.7832, [recall] 0.8867
# model=distilbert_base [f1] 0.808, [precision] 0.795, [recall] 0.884
# model=bert_base [f1] 0.8075, [precision] 0.7918, [recall] 0.8847
# <<<ensemble_ANY>>>: [f1] 0.7456, [precision] 0.687, [recall] 0.9246
# <<<ensemble_MAJOR>>>: [f1] 0.8653, [precision] 0.8927, [recall] 0.8894
# <<<ensemble_ALL>>>: [f1] 0.8589, [precision] 0.9436, [recall] 0.8415
# =========================================================
# THRESHOLD: 18.5
# model=xlm_roberta_base [f1] 0.8016, [precision] 0.7705, [recall] 0.8968
# model=distilbert_base [f1] 0.809, [precision] 0.7869, [recall] 0.8937
# model=bert_base [f1] 0.808, [precision] 0.7836, [recall] 0.895
# <<<ensemble_ANY>>>: [f1] 0.7395, [precision] 0.6722, [recall] 0.933
# <<<ensemble_MAJOR>>>: [f1] 0.8662, [precision] 0.884, [recall] 0.8993
# <<<ensemble_ALL>>>: [f1] 0.864, [precision] 0.9384, [recall] 0.8532
# =========================================================
# THRESHOLD: 19.0
# model=xlm_roberta_base [f1] 0.793, [precision] 0.7509, [recall] 0.9059
# model=distilbert_base [f1] 0.8084, [precision] 0.7767, [recall] 0.9044
# model=bert_base [f1] 0.806, [precision] 0.7718, [recall] 0.9046
# <<<ensemble_ANY>>>: [f1] 0.7275, [precision] 0.6504, [recall] 0.9412
# <<<ensemble_MAJOR>>>: [f1] 0.8656, [precision] 0.8734, [recall] 0.9093
# <<<ensemble_ALL>>>: [f1] 0.8677, [precision] 0.9307, [recall] 0.8645
# =========================================================
# THRESHOLD: 19.5
# model=xlm_roberta_base [f1] 0.7737, [precision] 0.7195, [recall] 0.9153
# model=distilbert_base [f1] 0.8021, [precision] 0.7599, [recall] 0.9143
# model=bert_base [f1] 0.7994, [precision] 0.7549, [recall] 0.9145
# <<<ensemble_ANY>>>: [f1] 0.7036, [precision] 0.6166, [recall] 0.9489
# <<<ensemble_MAJOR>>>: [f1] 0.8594, [precision] 0.8565, [recall] 0.9178
# <<<ensemble_ALL>>>: [f1] 0.8712, [precision] 0.9225, [recall] 0.8775
# =========================================================
# THRESHOLD: 20.0
# model=xlm_roberta_base [f1] 0.7383, [precision] 0.672, [recall] 0.9238
# model=distilbert_base [f1] 0.7875, [precision] 0.7344, [recall] 0.923
# model=bert_base [f1] 0.7843, [precision] 0.7288, [recall] 0.9229
# <<<ensemble_ANY>>>: [f1] 0.6624, [precision] 0.5666, [recall] 0.9546
# <<<ensemble_MAJOR>>>: [f1] 0.848, [precision] 0.8328, [recall] 0.9264
# <<<ensemble_ALL>>>: [f1] 0.8703, [precision] 0.909, [recall] 0.8886
# =========================================================
# THRESHOLD: 20.5
# model=xlm_roberta_base [f1] 0.6849, [precision] 0.6072, [recall] 0.9324
# model=distilbert_base [f1] 0.7616, [precision] 0.6968, [recall] 0.9319
# model=bert_base [f1] 0.756, [precision] 0.688, [recall] 0.9308
# <<<ensemble_ANY>>>: [f1] 0.6008, [precision] 0.4973, [recall] 0.9607
# <<<ensemble_MAJOR>>>: [f1] 0.8262, [precision] 0.7959, [recall] 0.9356
# <<<ensemble_ALL>>>: [f1] 0.8641, [precision] 0.8888, [recall] 0.8988
# =========================================================
# THRESHOLD: 21.0
# model=xlm_roberta_base [f1] 0.6113, [precision] 0.5247, [recall] 0.9409
# model=distilbert_base [f1] 0.7169, [precision] 0.6401, [recall] 0.9399
# model=bert_base [f1] 0.7094, [precision] 0.6285, [recall] 0.9392
# <<<ensemble_ANY>>>: [f1] 0.5147, [precision] 0.409, [recall] 0.9674
# <<<ensemble_MAJOR>>>: [f1] 0.7914, [precision] 0.7446, [recall] 0.9436
# <<<ensemble_ALL>>>: [f1] 0.8543, [precision] 0.864, [recall] 0.909
# =========================================================
# THRESHOLD: 21.5
# model=xlm_roberta_base [f1] 0.5211, [precision] 0.4311, [recall] 0.9505
# model=distilbert_base [f1] 0.6528, [precision] 0.5662, [recall] 0.9476
# model=bert_base [f1] 0.6402, [precision] 0.5493, [recall] 0.9476
# <<<ensemble_ANY>>>: [f1] 0.4132, [precision] 0.3132, [recall] 0.9739
# <<<ensemble_MAJOR>>>: [f1] 0.7358, [precision] 0.6703, [recall] 0.9523
# <<<ensemble_ALL>>>: [f1] 0.8352, [precision] 0.827, [recall] 0.9196

# %%
df_result = []
for th in np.arange(15, 22, 0.5):
    print("=========================================================")
    print(f"THRESHOLD: {th}")
    for model_name in model_dict.keys():
        f1score, precision, recall = get_cv(df, 
                                            model_dist_dict[model_name]["distances"],
                                            th,
                                            posting_id,
                                            model_dist_dict[model_name]["indices"],
                                            pred_name=model_name,
                                            min_n=4)
        print(f"model={model_name} [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")

    df["pred"] = df.apply(combine_predictions_any, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ANY>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_major, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_MAJOR>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
    
    df["pred"] = df.apply(combine_predictions_all, axis=1)
    f1score, precision, recall = calc_cv(df, col_name="pred")
    print(f"<<<ensemble_ALL>>>: [f1] {round(f1score, 4)}, [precision] {round(precision, 4)}, [recall] {round(recall, 4)}")
# Out:
# =========================================================
# THRESHOLD: 15.0
# model=xlm_roberta_base [f1] 0.7262, [precision] 0.7074, [recall] 0.8531
# model=distilbert_base [f1] 0.7279, [precision] 0.7148, [recall] 0.8529
# model=bert_base [f1] 0.7261, [precision] 0.712, [recall] 0.8496
# <<<ensemble_ANY>>>: [f1] 0.644, [precision] 0.5973, [recall] 0.8946
# <<<ensemble_MAJOR>>>: [f1] 0.8211, [precision] 0.8592, [recall] 0.8555
# <<<ensemble_ALL>>>: [f1] 0.8277, [precision] 0.9351, [recall] 0.8056
# =========================================================
# THRESHOLD: 15.5
# model=xlm_roberta_base [f1] 0.7306, [precision] 0.7066, [recall] 0.8599
# model=distilbert_base [f1] 0.732, [precision] 0.7134, [recall] 0.8597
# model=bert_base [f1] 0.7311, [precision] 0.7109, [recall] 0.8578
# <<<ensemble_ANY>>>: [f1] 0.6477, [precision] 0.5961, [recall] 0.9012
# <<<ensemble_MAJOR>>>: [f1] 0.8257, [precision] 0.858, [recall] 0.863
# <<<ensemble_ALL>>>: [f1] 0.8331, [precision] 0.9341, [recall] 0.8132
# =========================================================
# THRESHOLD: 16.0
# model=xlm_roberta_base [f1] 0.7341, [precision] 0.7052, [recall] 0.8661
# model=distilbert_base [f1] 0.7357, [precision] 0.7116, [recall] 0.8662
# model=bert_base [f1] 0.7357, [precision] 0.7097, [recall] 0.8656
# <<<ensemble_ANY>>>: [f1] 0.6508, [precision] 0.5943, [recall] 0.9074
# <<<ensemble_MAJOR>>>: [f1] 0.8298, [precision] 0.8567, [recall] 0.8699
# <<<ensemble_ALL>>>: [f1] 0.8379, [precision] 0.9322, [recall] 0.8206
# =========================================================
# THRESHOLD: 16.5
# model=xlm_roberta_base [f1] 0.738, [precision] 0.7032, [recall] 0.8739
# model=distilbert_base [f1] 0.7398, [precision] 0.7094, [recall] 0.8741
# model=bert_base [f1] 0.7402, [precision] 0.7075, [recall] 0.8742
# <<<ensemble_ANY>>>: [f1] 0.6538, [precision] 0.5914, [recall] 0.915
# <<<ensemble_MAJOR>>>: [f1] 0.834, [precision] 0.855, [recall] 0.8777
# <<<ensemble_ALL>>>: [f1] 0.8433, [precision] 0.9303, [recall] 0.8295
# =========================================================
# THRESHOLD: 17.0
# model=xlm_roberta_base [f1] 0.742, [precision] 0.7007, [recall] 0.8818
# model=distilbert_base [f1] 0.7436, [precision] 0.707, [recall] 0.8821
# model=bert_base [f1] 0.7442, [precision] 0.7049, [recall] 0.8824
# <<<ensemble_ANY>>>: [f1] 0.6562, [precision] 0.5882, [recall] 0.9218
# <<<ensemble_MAJOR>>>: [f1] 0.838, [precision] 0.8526, [recall] 0.8857
# <<<ensemble_ALL>>>: [f1] 0.849, [precision] 0.9282, [recall] 0.8389
# =========================================================
# THRESHOLD: 17.5
# model=xlm_roberta_base [f1] 0.7454, [precision] 0.6973, [recall] 0.8906
# model=distilbert_base [f1] 0.747, [precision] 0.7039, [recall] 0.8899
# model=bert_base [f1] 0.7474, [precision] 0.7019, [recall] 0.8902
# <<<ensemble_ANY>>>: [f1] 0.6576, [precision] 0.5837, [recall] 0.9287
# <<<ensemble_MAJOR>>>: [f1] 0.842, [precision] 0.8497, [recall] 0.8942
# <<<ensemble_ALL>>>: [f1] 0.8538, [precision] 0.9253, [recall] 0.8478
# =========================================================
# THRESHOLD: 18.0
# model=xlm_roberta_base [f1] 0.7469, [precision] 0.6913, [recall] 0.8989
# model=distilbert_base [f1] 0.7498, [precision] 0.7005, [recall] 0.8978
# model=bert_base [f1] 0.7493, [precision] 0.6977, [recall] 0.8978
# <<<ensemble_ANY>>>: [f1] 0.6566, [precision] 0.5773, [recall] 0.9345
# <<<ensemble_MAJOR>>>: [f1] 0.8452, [precision] 0.8455, [recall] 0.9032
# <<<ensemble_ALL>>>: [f1] 0.858, [precision] 0.9223, [recall] 0.8568
# =========================================================
# THRESHOLD: 18.5
# model=xlm_roberta_base [f1] 0.7454, [precision] 0.6824, [recall] 0.9067
# model=distilbert_base [f1] 0.7513, [precision] 0.6949, [recall] 0.906
# model=bert_base [f1] 0.7501, [precision] 0.6919, [recall] 0.906
# <<<ensemble_ANY>>>: [f1] 0.653, [precision] 0.5672, [recall] 0.9411
# <<<ensemble_MAJOR>>>: [f1] 0.846, [precision] 0.8389, [recall] 0.9112
# <<<ensemble_ALL>>>: [f1] 0.8621, [precision] 0.918, [recall] 0.8663
# =========================================================
# THRESHOLD: 19.0
# model=xlm_roberta_base [f1] 0.7394, [precision] 0.6686, [recall] 0.9141
# model=distilbert_base [f1] 0.7513, [precision] 0.6877, [recall] 0.9145
# model=bert_base [f1] 0.7492, [precision] 0.6837, [recall] 0.9139
# <<<ensemble_ANY>>>: [f1] 0.6451, [precision] 0.5525, [recall] 0.9478
# <<<ensemble_MAJOR>>>: [f1] 0.8455, [precision] 0.8309, [recall] 0.9188
# <<<ensemble_ALL>>>: [f1] 0.8651, [precision] 0.912, [recall] 0.8758
# =========================================================
# THRESHOLD: 19.5
# model=xlm_roberta_base [f1] 0.7243, [precision] 0.6453, [recall] 0.9217
# model=distilbert_base [f1] 0.747, [precision] 0.6759, [recall] 0.9223
# model=bert_base [f1] 0.7447, [precision] 0.672, [recall] 0.9214
# <<<ensemble_ANY>>>: [f1] 0.6279, [precision] 0.529, [recall] 0.9532
# <<<ensemble_MAJOR>>>: [f1] 0.8402, [precision] 0.8175, [recall] 0.9257
# <<<ensemble_ALL>>>: [f1] 0.8677, [precision] 0.905, [recall] 0.8865
# =========================================================
# THRESHOLD: 20.0
# model=xlm_roberta_base [f1] 0.695, [precision] 0.608, [recall] 0.9283
# model=distilbert_base [f1] 0.7364, [precision] 0.6578, [recall] 0.9294
# model=bert_base [f1] 0.7337, [precision] 0.6538, [recall] 0.9278
# <<<ensemble_ANY>>>: [f1] 0.5966, [precision] 0.4925, [recall] 0.9576
# <<<ensemble_MAJOR>>>: [f1] 0.8309, [precision] 0.7991, [recall] 0.9325
# <<<ensemble_ALL>>>: [f1] 0.8665, [precision] 0.8939, [recall] 0.8953
# =========================================================
# THRESHOLD: 20.5
# model=xlm_roberta_base [f1] 0.649, [precision] 0.5549, [recall] 0.9355
# model=distilbert_base [f1] 0.7155, [precision] 0.6288, [recall] 0.9366
# model=bert_base [f1] 0.711, [precision] 0.6224, [recall] 0.9344
# <<<ensemble_ANY>>>: [f1] 0.5472, [precision] 0.4386, [recall] 0.9627
# <<<ensemble_MAJOR>>>: [f1] 0.8108, [precision] 0.767, [recall] 0.9398
# <<<ensemble_ALL>>>: [f1] 0.8607, [precision] 0.8763, [recall] 0.904
# =========================================================
# THRESHOLD: 21.0
# model=xlm_roberta_base [f1] 0.583, [precision] 0.4842, [recall] 0.9429
# model=distilbert_base [f1] 0.6779, [precision] 0.5836, [recall] 0.9431
# model=bert_base [f1] 0.6717, [precision] 0.5745, [recall] 0.9417
# <<<ensemble_ANY>>>: [f1] 0.4752, [precision] 0.3671, [recall] 0.9684
# <<<ensemble_MAJOR>>>: [f1] 0.7775, [precision] 0.72, [recall] 0.9466
# <<<ensemble_ALL>>>: [f1] 0.8512, [precision] 0.854, [recall] 0.9126
# =========================================================
# THRESHOLD: 21.5
# model=xlm_roberta_base [f1] 0.5008, [precision] 0.4024, [recall] 0.9517
# model=distilbert_base [f1] 0.6217, [precision] 0.5218, [recall] 0.9498
# model=bert_base [f1] 0.6106, [precision] 0.5073, [recall] 0.9492
# <<<ensemble_ANY>>>: [f1] 0.387, [precision] 0.2863, [recall] 0.9745
# <<<ensemble_MAJOR>>>: [f1] 0.7241, [precision] 0.6506, [recall] 0.9541
# <<<ensemble_ALL>>>: [f1] 0.8321, [precision] 0.8185, [recall] 0.9221
